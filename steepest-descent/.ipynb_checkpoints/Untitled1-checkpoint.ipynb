# %%
import numpy as np
import numpy.linalg as la

import scipy.optimize as sopt
import sympy as scm
import matplotlib.pyplot as pt
from mpl_toolkits.mplot3d import axes3d

# %%
def grad(f):
    df = []
    df.append(scm.diff(f, x))
    df.append(scm.diff(f, y))
    arr = np.array(df)
    return arr

x, y = scm.symbols('x y')
fun = 4*x**2 - 4*x*y + 2*y**2

dff = grad(fun)
def f(x):
#     return fun.subs([(x, X[0]), (y, X[1])])
    return 4*x[0]**2 - 4*x[0]*x[1] + 2*x[1]**2

def df(x):
#     return np.array([scm.diff(f, x).subs([(x, X[0]), (y, X[1])]), scm.diff(f, y).subs([(x, X[0]), (y, X[1])])])
    return np.array([8*x[0] - 4*x[1], -4*x[0] + 4*x[1]])

# %%
fig = pt.figure()
ax = fig.gca(projection="3d")

xmesh, ymesh = np.mgrid[-2:2:50j,-2:2:50j]
fmesh = f(np.array([xmesh, ymesh]))
ax.plot_surface(xmesh, ymesh, fmesh)
# Out:
# /tmp/ipykernel_39715/157005317.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_39715/157005317.py in <module>
#       3
#       4 xmesh, ymesh = np.mgrid[-2:2:50j,-2:2:50j]
# ----> 5 fmesh = f(np.array([xmesh, ymesh]))
#       6 ax.plot_surface(xmesh, ymesh, fmesh)
#
# /tmp/ipykernel_39715/2470521908.py in f(X)
#      12 def f(X):
#      13 #     return fun.subs([(x, X[0]), (y, X[1])])
# ---> 14     return 4*x[0]**2 - 4*x[0]*x[1] + 2*x[1]**2
#      15
#      16 def df(X):
#
# TypeError: 'Symbol' object is not subscriptable

# %%
pt.axis("equal")
pt.contour(xmesh, ymesh, fmesh)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_39715/1077639162.py in <module>
#       1 pt.axis("equal")
# ----> 2 pt.contour(xmesh, ymesh, fmesh)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in contour(data, *args, **kwargs)
#    2482 @_copy_docstring_and_deprecators(Axes.contour)
#    2483 def contour(*args, data=None, **kwargs):
# -> 2484     __ret = gca().contour(
#    2485         *args, **({"data": data} if data is not None else {}),
#    2486         **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in contour(self, *args, **kwargs)
#    6295         """
#    6296         kwargs['filled'] = False
# -> 6297         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6298         self._request_autoscale_view()
#    6299         return contours
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     810         self._transform = transform
#     811
# --> 812         kwargs = self._process_args(*args, **kwargs)
#     813         self._process_levels()
#     814
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py in _process_args(self, corner_mask, *args, **kwargs)
#    1444             self._corner_mask = corner_mask
#    1445
# -> 1446             x, y, z = self._contour_args(args, kwargs)
#    1447
#    1448             _mask = ma.getmask(z)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1483             args = args[1:]
#    1484         elif Nargs <= 4:
# -> 1485             x, y, z = self._check_xyz(args[:3], kwargs)
#    1486             args = args[3:]
#    1487         else:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1508         x = np.asarray(x, dtype=np.float64)
#    1509         y = np.asarray(y, dtype=np.float64)
# -> 1510         z = ma.asarray(args[2], dtype=np.float64)
#    1511
#    1512         if z.ndim != 2:
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/ma/core.py in asarray(a, dtype, order)
#    7950     """
#    7951     order = order or 'C'
# -> 7952     return masked_array(a, dtype=dtype, copy=False, keep_mask=True,
#    7953                         subok=False, order=order)
#    7954
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/ma/core.py in __new__(cls, data, mask, dtype, copy, subok, ndmin, fill_value, keep_mask, hard_mask, shrink, order)
#    2827         """
#    2828         # Process data.
# -> 2829         _data = np.array(data, dtype=dtype, copy=copy,
#    2830                          order=order, subok=True, ndmin=ndmin)
#    2831         _baseclass = getattr(data, '_baseclass', type(_data))
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/core/expr.py in __float__(self)
#     343         if result.is_number and result.as_real_imag()[1]:
#     344             raise TypeError("Cannot convert complex to float")
# --> 345         raise TypeError("Cannot convert expression to float")
#     346
#     347     def __complex__(self):
#
# TypeError: Cannot convert expression to float

# %%
guesses = [np.array([2, 3])]

# %%
def f1d(alpha):
    return f(x + alpha*s)
mma = 0
while mma < 15:
    x = guesses[-1]
    s = -df(x)

    alpha_opt = sopt.golden(f1d)
#     print(alpha_opt)
    next_guess = x + alpha_opt * s
    guesses.append(next_guess)

#     print(next_guess)
    mma += 1

for word in guesses:
    print(word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_39715/1427213089.py in <module>
#       6     s = -df(x)
#       7
# ----> 8     alpha_opt = sopt.golden(f1d)
#       9 #     print(alpha_opt)
#      10     next_guess = x + alpha_opt * s
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in golden(func, args, brack, tol, full_output, maxiter)
#    2578     """
#    2579     options = {'xtol': tol, 'maxiter': maxiter}
# -> 2580     res = _minimize_scalar_golden(func, brack, args, **options)
#    2581     if full_output:
#    2582         return res['x'], res['fun'], res['nfev']
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_scalar_golden(func, brack, args, xtol, maxiter, disp, **unknown_options)
#    2605     tol = xtol
#    2606     if brack is None:
# -> 2607         xa, xb, xc, fa, fb, fc, funcalls = bracket(func, args=args)
#    2608     elif len(brack) == 2:
#    2609         xa, xb, xc, fa, fb, fc, funcalls = bracket(func, xa=brack[0],
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in bracket(func, xa, xb, args, grow_limit, maxiter)
#    2752     fa = func(*(xa,) + args)
#    2753     fb = func(*(xb,) + args)
# -> 2754     if (fa < fb):                      # Switch so fa > fb
#    2755         xa, xb = xb, xa
#    2756         fa, fb = fb, fa
#
# ~/anaconda3/lib/python3.9/site-packages/sympy/core/relational.py in __bool__(self)
#     509
#     510     def __bool__(self):
# --> 511         raise TypeError("cannot determine truth value of Relational")
#     512
#     513     def _eval_as_set(self):
#
# TypeError: cannot determine truth value of Relational

# %%
pt.axis("equal")
pt.contour(xmesh, ymesh, fmesh, 50)
it_array = np.array(guesses)
pt.plot(it_array.T[0], it_array.T[1], "x-")
